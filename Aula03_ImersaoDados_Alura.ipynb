# %% [markdown]
# <a href="https://colab.research.google.com/github/WeversonRibeiro/imersao_dados_alura3/blob/main/Aula03_ImersaoDados_Alura.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# URL da base de dados
url_dados = 'https://github.com/alura-cursos/imersaodados3/blob/main/dados/dados_experimentos.zip?raw=true'

# Variável que guarda as infomações que serão lidas pelo "pd.read_csv" vindas da base de dados (url_dados) e descompacta da pasta zipada
dados = pd.read_csv(url_dados, compression = 'zip')

#print(dados)
dados # Dataframe
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0      id_000644bb2     com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1      id_000779bfc     com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2      id_000a6266a     com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3      id_0015fd391     com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4      id_001626bd3     com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.2084 -0.1224 -0.2715  0.3689
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# 23812  id_fffcb9e7c     com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
# ...

# %%
dados.head()
# Out:
#              id tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3  id_0015fd391  com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4  id_001626bd3  com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
#
# [5 rows x 877 columns]

# %%
# plotar uma tabela de frequência
pd.crosstab(dados['dose'], dados['tempo'])
# Out:
# tempo    24    48    72
# dose
# D1     3886  4354  3907
# D2     3886  3896  3885

# %%
pd.crosstab([dados['dose'], dados['tempo']], dados['tratamento'])
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24              301       3585
#      48              343       4011
#      72              307       3600
# D2   24              305       3581
#      48              305       3591
#      72              305       3580

# %%
# Verificar as proporções
pd.crosstab([dados['dose'], dados['tempo']], dados['tratamento'], normalize = True)
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24         0.012640   0.150542
#      48         0.014403   0.168430
#      72         0.012892   0.151172
# D2   24         0.012808   0.150374
#      48         0.012808   0.150794
#      72         0.012808   0.150332

# %%
pd.crosstab([dados['dose'], dados['tempo']], dados['tratamento'], normalize = 'index')
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24         0.077458   0.922542
#      48         0.078778   0.921222
#      72         0.078577   0.921423
# D2   24         0.078487   0.921513
#      48         0.078285   0.921715
#      72         0.078507   0.921493

# %%
# agregar função
pd.crosstab([dados['dose'], dados['tempo']], dados['tratamento'], values = dados['g-0'], aggfunc = 'mean')
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24        -0.251760   0.367996
#      48        -0.122773   0.412469
#      72        -0.295271   0.286250
# D2   24         0.010754   0.115253
#      48         0.013174   0.214480
#      72         0.070250   0.253439

# %%
# slice da base de dados
dados[['g-0', 'g-3']]
# Out:
#           g-0     g-3
# 0      1.0620 -0.6208
# 1      0.0743  0.0604
# 2      0.6280 -0.0764
# 3     -0.5138  0.5288
# 4     -0.3254  0.6919
# ...       ...     ...
# 23809  0.1394 -0.5080
# 23810 -1.3260  0.9905
# 23811  0.3942 -0.7389
# 23812  0.6660  0.2044
# 23813 -0.8598  0.7952
#
# [23814 rows x 2 columns]

# %%
# plotar um gráfico de dispersão
import seaborn as sns
sns.set()

sns.scatterplot(x = 'g-0', y = 'g-3', data = dados)

# %%
sns.scatterplot(x = 'g-0', y = 'g-8', data = dados)

# %%
# gráfico de dispersão com linha de tendência
sns.lmplot(data = dados, x = 'g-0', y = 'g-8', line_kws = {'color': 'red'})

# %%
sns.lmplot(data = dados, x = 'g-0', y = 'g-8', line_kws = {'color': 'red'}, col = 'tratamento', row = 'tempo')

# %%
# calcular a correlação dos valores
dados.loc[:, 'g-0':'g-771'].corr()
# Out:
#             g-0       g-1       g-2  ...     g-769     g-770     g-771
# g-0    1.000000  0.086032  0.176188  ... -0.127375 -0.514201  0.405908
# g-1    0.086032  1.000000 -0.054518  ... -0.006866 -0.095108 -0.032233
# g-2    0.176188 -0.054518  1.000000  ...  0.014489 -0.078661  0.103985
# g-3    0.011266 -0.027855  0.042633  ... -0.206077 -0.002142  0.058219
# g-4    0.403153  0.193647  0.013968  ... -0.172727 -0.363673  0.250713
# ...         ...       ...       ...  ...       ...       ...       ...
# g-767 -0.052622 -0.003378 -0.053149  ...  0.065450  0.008603 -0.001136
# g-768  0.300241 -0.030756  0.115415  ...  0.079364 -0.382607  0.351651
# g-769 -0.127375 -0.006866  0.014489  ...  1.000000  0.135853 -0.083713
# g-770 -0.514201 -0.095108 -0.078661  ...  0.135853  1.000000 -0.425063
# g-771  0.405908 -0.032233  0.103985  ... -0.083713 -0.425063  1.000000
#
# [772 rows x 772 columns]

# %%
# Compute the correlation matrix
corr = dados.loc[:, 'g-0':'g-50'].corr()

# %%
# plotar um gráfico de coorelação para os dados
# pesquisar sobre 'correlation matrix seaborn' para verificar o código na documentação (remover o 'vmax') 

import numpy as np
import matplotlib.pyplot as plt

# Compute the correlation matrix
#corr = dados.loc[:, 'g-0':'g-50'].corr()

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %%
corr_celular = dados.loc[:, 'c-0':'c-50'].corr()

# %%
# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr_celular, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr_celular, mask=mask, cmap=cmap, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %% [markdown]
# ### Desafio 01 - Criar tabelas de frequência com pandas.groupby().

# %%
dados.groupby(by = ['dose', 'tempo'])['tratamento'].value_counts().unstack()
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24              301       3585
#      48              343       4011
#      72              307       3600
# D2   24              305       3581
#      48              305       3591
#      72              305       3580

# %% [markdown]
# ### Desafio 02 - Normalizar o crosstab pela coluna.

# %%
pd.crosstab([dados['dose'], dados['tempo']], dados['tratamento'], normalize = 'columns')
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24         0.161308   0.163341
#      48         0.183816   0.182750
#      72         0.164523   0.164024
# D2   24         0.163451   0.163158
#      48         0.163451   0.163614
#      72         0.163451   0.163113

# %% [markdown]
# ### Desafio 03 - Explorar outros agregadores.

# %%
dados.describe()
# Out:
#               tempo           g-0  ...          c-98          c-99
# count  23814.000000  23814.000000  ...  23814.000000  23814.000000
# mean      48.020156      0.248366  ...     -0.470252     -0.301505
# std       19.402807      1.393399  ...      1.834828      1.407918
# min       24.000000     -5.513000  ...    -10.000000    -10.000000
# 25%       24.000000     -0.473075  ...     -0.592600     -0.562900
# 50%       48.000000     -0.008850  ...      0.014000     -0.019500
# 75%       72.000000      0.525700  ...      0.461275      0.438650
# max       72.000000     10.000000  ...      3.111000      3.805000
#
# [8 rows x 873 columns]

# %%
pd.crosstab([dados['dose'], dados['tempo']], dados['tratamento'], values = dados['g-0'], aggfunc = 'count')
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24              301       3585
#      48              343       4011
#      72              307       3600
# D2   24              305       3581
#      48              305       3591
#      72              305       3580

# %%
pd.crosstab([dados['dose'], dados['tempo']], dados['tratamento'], values = dados['g-0'], aggfunc = 'min')
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24           -2.370     -5.183
#      48           -3.276     -5.420
#      72           -2.086     -5.261
# D2   24           -2.135     -5.233
#      48           -4.859     -4.567
#      72           -1.909     -5.513

# %%
pd.crosstab([dados['dose'], dados['tempo']], dados['tratamento'], values = dados['g-0'], aggfunc = 'max')
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24            3.226      9.908
#      48            3.423     10.000
#      72            2.584      9.355
# D2   24            2.601      7.167
#      48            4.335     10.000
#      72            4.670     10.000

# %% [markdown]
# ### Desafio 04 - Explorar o melt.

# %%
pd.melt(dados, id_vars = ['dose', 'tempo'], value_vars = ['g-8'])
# Out:
#       dose  tempo variable   value
# 0       D1     24      g-8  0.5548
# 1       D1     72      g-8 -0.4047
# 2       D1     48      g-8  0.0065
# 3       D1     48      g-8 -0.1321
# 4       D2     72      g-8 -0.8789
# ...    ...    ...      ...     ...
# 23809   D2     24      g-8 -0.4726
# 23810   D2     24      g-8  0.5112
# 23811   D2     48      g-8 -0.0340
# 23812   D1     24      g-8  0.4299
# 23813   D1     72      g-8  3.0790
#
# [23814 rows x 4 columns]

# %%
pd.melt(dados, id_vars = ['dose', 'tratamento'], value_vars = ['c-0'])
# Out:
#       dose    tratamento variable   value
# 0       D1     com_droga      c-0 -0.0600
# 1       D1     com_droga      c-0  0.0927
# 2       D1     com_droga      c-0 -0.1312
# 3       D1     com_droga      c-0 -0.3998
# 4       D2     com_droga      c-0 -0.3774
# ...    ...           ...      ...     ...
# 23809   D2     com_droga      c-0  0.4224
# 23810   D2     com_droga      c-0  0.2144
# 23811   D2  com_controle      c-0  1.0650
# 23812   D1     com_droga      c-0  0.5377
# 23813   D1     com_droga      c-0 -2.3890
#
# [23814 rows x 4 columns]

# %%
pd.melt(dados, id_vars = ['tratamento', 'tempo'], value_vars = ['dose'])
# Out:
#          tratamento  tempo variable value
# 0         com_droga     24     dose    D1
# 1         com_droga     72     dose    D1
# 2         com_droga     48     dose    D1
# 3         com_droga     48     dose    D1
# 4         com_droga     72     dose    D2
# ...             ...    ...      ...   ...
# 23809     com_droga     24     dose    D2
# 23810     com_droga     24     dose    D2
# 23811  com_controle     48     dose    D2
# 23812     com_droga     24     dose    D1
# 23813     com_droga     72     dose    D1
#
# [23814 rows x 4 columns]

# %% [markdown]
# ### Desafio 05 - Calcular e analisar a correlação entre os g's e c's. Refletir sobre os efeitos biológicos.

# %%
g_dados = dados[dados['dose']=='D1'].loc[:, 'g-0':'g-50']
c_dados = dados[dados['dose']=='D1'].loc[:, 'c-0':'c-50']

# %%
data_new_dados = pd.concat([g_dados, c_dados], axis = 1)
data_new_dados.corr()
# Out:
#            g-0       g-1       g-2  ...      c-48      c-49      c-50
# g-0   1.000000  0.071546  0.176710  ... -0.603942 -0.617839 -0.604046
# g-1   0.071546  1.000000 -0.050010  ...  0.003686  0.035052  0.024609
# g-2   0.176710 -0.050010  1.000000  ... -0.163114 -0.171502 -0.157127
# g-3   0.023815 -0.011016  0.040901  ... -0.062495 -0.036906 -0.014167
# g-4   0.410954  0.164478  0.025538  ... -0.360632 -0.362597 -0.373212
# ...        ...       ...       ...  ...       ...       ...       ...
# c-46 -0.610167 -0.007487 -0.170008  ...  0.823017  0.820953  0.828521
# c-47 -0.660685  0.009141 -0.177350  ...  0.853127  0.854897  0.849757
# c-48 -0.603942  0.003686 -0.163114  ...  1.000000  0.856524  0.868251
# c-49 -0.617839  0.035052 -0.171502  ...  0.856524  1.000000  0.862033
# c-50 -0.604046  0.024609 -0.157127  ...  0.868251  0.862033  1.000000
#
# [102 rows x 102 columns]

# %%
# Compute the correlation matrix
corr_dados_new = data_new_dados.corr()
corr_dados_new = corr_dados_new.loc['c-0':'c-50', 'g-0':'g-50']

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr_dados_new, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr_dados_new, mask=mask, cmap=cmap, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %% [markdown]
# ### Desafio 06 - Estudar o código que plota a matriz de correlação (heatmap).

# %%
# Compute the correlation matrix
corr = d.corr()

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %% [markdown]
# O código primeiramente computa uma matriz de correlações entre os dados e gera uma máscara para o triângulo superior. Logo após, é setado os valores do tamanho das figuras com o uso do matplotlib. É gerado um mapa de cores personalizado e desenhado um mapa de calor com as proporções.

# %% [markdown]
# ### Desafio 07 - Resumo do que você aprendeu com os dados.

# %% [markdown]
# - Encontrar correlações entre os dados com o uso do gráfico de coorelações e tabelas crosstab.
