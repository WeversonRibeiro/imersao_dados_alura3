# %% [markdown]
# <a href="https://colab.research.google.com/github/WeversonRibeiro/imersao_dados_alura3/blob/main/Aula04_ImersaoDados_Alura.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# URL da base de dados
url_dados = 'https://github.com/alura-cursos/imersaodados3/blob/main/dados/dados_experimentos.zip?raw=true'

# Variável que guarda as infomações que serão lidas pelo "pd.read_csv" vindas da base de dados (url_dados) e descompacta da pasta zipada
dados = pd.read_csv(url_dados, compression = 'zip')

#print(dados)
dados # Dataframe
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0      id_000644bb2     com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1      id_000779bfc     com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2      id_000a6266a     com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3      id_0015fd391     com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4      id_001626bd3     com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.2084 -0.1224 -0.2715  0.3689
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# 23812  id_fffcb9e7c     com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
# ...

# %%
# renomear a coluna 'droga' > 'composto' (inplace = True, para gravar a alteração)
mapa = {'droga': 'composto'}
dados.rename(columns = mapa, inplace = True)

# %%
dados.head()
# Out:
#              id tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3  id_0015fd391  com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4  id_001626bd3  com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
#
# [5 rows x 877 columns]

# %%
# URL da base de dados
url_dados_resultados = 'https://github.com/alura-cursos/imersao-dados-desafio-final/blob/main/Dados/dados_resultados.csv?raw=true'

# Variável que guarda as infomações que serão lidas pelo "pd.read_csv" vindas da base de dados (url_dados) e descompacta da pasta zipada
dados_resultados = pd.read_csv(url_dados_resultados)

#print(dados_resultados)
dados_resultados # Dataframe
# Out:
#                  id  ...  wnt_inhibitor
# 0      id_000644bb2  ...              0
# 1      id_000779bfc  ...              0
# 2      id_000a6266a  ...              0
# 3      id_0015fd391  ...              0
# 4      id_001626bd3  ...              0
# ...             ...  ...            ...
# 23809  id_fffb1ceed  ...              0
# 23810  id_fffb70c0c  ...              0
# 23811  id_fffc1c3f4  ...              0
# 23812  id_fffcb9e7c  ...              0
# 23813  id_ffffdd77b  ...              0
#
# [23814 rows x 207 columns]

# %%
dados_resultados.head()
# Out:
#              id  ...  wnt_inhibitor
# 0  id_000644bb2  ...              0
# 1  id_000779bfc  ...              0
# 2  id_000a6266a  ...              0
# 3  id_0015fd391  ...              0
# 4  id_001626bd3  ...              0
#
# [5 rows x 207 columns]

# %%
# Ver valores unicos
dados_resultados['acat_inhibitor'].unique()
# Out:
# array([0, 1])

# %%
dados_resultados['acetylcholine_receptor_agonist'].unique()
# Out:
# array([0, 1])

# %%
# ver os tipos das colunas
dados_resultados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23814 entries, 0 to 23813
# Columns: 207 entries, id to wnt_inhibitor
# dtypes: int64(206), object(1)
# memory usage: 37.6+ MB

# %%
# contagem dos mecanismos de ação (0 = Não ativado, 1 = Ativado)
# do maior para o menor
# selecionando apenas as colunas do tipo inteiro

# uma forma de selecionar é dar um drop na primeira coluna e 'axis = 1' para informar que o dado é uma coluna
#mec_acao_ativado = dados_resultados.drop('id', axis = 1).sum().sort_values(ascending = False)

mec_acao_ativado = dados_resultados.select_dtypes('int64').sum().sort_values(ascending = False)
mec_acao_ativado
# Out:
# nfkb_inhibitor                                832
# proteasome_inhibitor                          726
# cyclooxygenase_inhibitor                      435
# dopamine_receptor_antagonist                  424
# serotonin_receptor_antagonist                 404
#                                              ...
# protein_phosphatase_inhibitor                   6
# autotaxin_inhibitor                             6
# diuretic                                        6
# erbb2_inhibitor                                 1
# atp-sensitive_potassium_channel_antagonist      1
# Length: 206, dtype: int64

# %%
# contagem pelas linhas
dados_resultados.drop('id', axis = 1).sum(axis = 1)
# Out:
# 0        1
# 1        0
# 2        3
# 3        0
# 4        1
#         ..
# 23809    1
# 23810    1
# 23811    0
# 23812    1
# 23813    0
# Length: 23814, dtype: int64

# %%
# criar duas novas colunas
dados_resultados['n_moa'] = dados_resultados.drop('id', axis = 1).sum(axis = 1)

# %%
# criar duas novas colunas
#dados_resultados['n_moa'] = dados_resultados.drop('id', axis = 1).sum(axis = 1)
dados_resultados['ativo_moa'] = (dados_resultados['n_moa'] != 0)
dados_resultados.head()
# Out:
#              id  5-alpha_reductase_inhibitor  ...  n_moa  ativo_moa
# 0  id_000644bb2                            0  ...      1       True
# 1  id_000779bfc                            0  ...      0      False
# 2  id_000a6266a                            0  ...      3       True
# 3  id_0015fd391                            0  ...      0      False
# 4  id_001626bd3                            0  ...      1       True
#
# [5 rows x 209 columns]

# %%
# juntar as informações das duas tabelas (merge), selecionando algumas colunas
dados_totais = pd.merge(dados, dados_resultados[['id', 'n_moa', 'ativo_moa']], on = 'id')
dados_totais.head()
# Out:
#              id tratamento  tempo dose  ...    c-98    c-99  n_moa  ativo_moa
# 0  id_000644bb2  com_droga     24   D1  ...  0.3801  0.4176      1       True
# 1  id_000779bfc  com_droga     72   D1  ...  0.6077  0.7371      0      False
# 2  id_000a6266a  com_droga     48   D1  ... -1.4080  0.6931      3       True
# 3  id_0015fd391  com_droga     48   D1  ... -0.3876 -0.8154      0      False
# 4  id_001626bd3  com_droga     72   D2  ... -0.3786  0.7125      1       True
#
# [5 rows x 879 columns]

# %%
# verificar se os mecanismos de ação foram ativados para tratamento com controle
dados_totais.query('tratamento == "com_controle"')['ativo_moa'].value_counts()
# Out:
# False    1866
# Name: ativo_moa, dtype: int64

# %%
# verificar se os mecanismos de ação foram ativados para tratamento com droga
dados_totais.query('tratamento == "com_droga"')['ativo_moa'].value_counts()
# Out:
# True     14447
# False     7501
# Name: ativo_moa, dtype: int64

# %%
# plotar um gráfico com os compostos mais utilizados
import seaborn as sns
import matplotlib.pyplot as plt

composto_principal = dados_totais['composto'].value_counts().index[:5]

sns.set()
plt.figure(figsize = (12,8))
sns.boxplot(data = dados_totais.query('composto in @composto_principal'), y = 'g-0', x = 'composto', hue = 'ativo_moa')

# %% [markdown]
# ### Desafio 01 - Encontrar o top 10 das ações dos MOA (inibidor, antagonista...).

# %%
contador_moa = dados_resultados.drop(['id', 'n_moa', 'ativo_moa'], axis = 1).sum().sort_values(ascending = False).reset_index()
contador_moa.columns = ['MOA', 'Total']
contador_moa
# Out:
#                                             MOA  Total
# 0                                nfkb_inhibitor    832
# 1                          proteasome_inhibitor    726
# 2                      cyclooxygenase_inhibitor    435
# 3                  dopamine_receptor_antagonist    424
# 4                 serotonin_receptor_antagonist    404
# ..                                          ...    ...
# 201               protein_phosphatase_inhibitor      6
# 202                         autotaxin_inhibitor      6
# 203                                    diuretic      6
# 204                             erbb2_inhibitor      1
# 205  atp-sensitive_potassium_channel_antagonist      1
#
# [206 rows x 2 columns]

# %% [markdown]
# ### Desafio 02 - Criar a coluna 'eh_controle' para quando na linha tratamento == com_controle.

# %%
dados_totais['eh_controle'] = dados_totais['tratamento'] == 'com_controle'
dados_totais
# Out:
#                  id    tratamento  tempo  ... n_moa ativo_moa  eh_controle
# 0      id_000644bb2     com_droga     24  ...     1      True        False
# 1      id_000779bfc     com_droga     72  ...     0     False        False
# 2      id_000a6266a     com_droga     48  ...     3      True        False
# 3      id_0015fd391     com_droga     48  ...     0     False        False
# 4      id_001626bd3     com_droga     72  ...     1      True        False
# ...             ...           ...    ...  ...   ...       ...          ...
# 23809  id_fffb1ceed     com_droga     24  ...     1      True        False
# 23810  id_fffb70c0c     com_droga     24  ...     1      True        False
# 23811  id_fffc1c3f4  com_controle     48  ...     0     False         True
# 23812  id_fffcb9e7c     com_droga     24  ...     1      True        False
# 23813  id_ffffdd77b     com_droga     72  ...     0     False        False
#
# [23814 rows x 880 columns]

# %% [markdown]
# ### Desafio 03 - Criar três colunas para indicar o tempo 24, 48, 72.

# %%
dados_totais['eh_24h'] = dados_totais['tratamento'] == 24
dados_totais
# Out:
#                  id    tratamento  tempo  ... ativo_moa eh_controle  eh_24h
# 0      id_000644bb2     com_droga     24  ...      True       False   False
# 1      id_000779bfc     com_droga     72  ...     False       False   False
# 2      id_000a6266a     com_droga     48  ...      True       False   False
# 3      id_0015fd391     com_droga     48  ...     False       False   False
# 4      id_001626bd3     com_droga     72  ...      True       False   False
# ...             ...           ...    ...  ...       ...         ...     ...
# 23809  id_fffb1ceed     com_droga     24  ...      True       False   False
# 23810  id_fffb70c0c     com_droga     24  ...      True       False   False
# 23811  id_fffc1c3f4  com_controle     48  ...     False        True   False
# 23812  id_fffcb9e7c     com_droga     24  ...      True       False   False
# 23813  id_ffffdd77b     com_droga     72  ...     False       False   False
#
# [23814 rows x 881 columns]

# %%
dados_totais['eh_48h'] = dados_totais['tratamento'] == 48
dados_totais
# Out:
#                  id    tratamento  tempo  ... eh_controle eh_24h  eh_48h
# 0      id_000644bb2     com_droga     24  ...       False  False   False
# 1      id_000779bfc     com_droga     72  ...       False  False   False
# 2      id_000a6266a     com_droga     48  ...       False  False   False
# 3      id_0015fd391     com_droga     48  ...       False  False   False
# 4      id_001626bd3     com_droga     72  ...       False  False   False
# ...             ...           ...    ...  ...         ...    ...     ...
# 23809  id_fffb1ceed     com_droga     24  ...       False  False   False
# 23810  id_fffb70c0c     com_droga     24  ...       False  False   False
# 23811  id_fffc1c3f4  com_controle     48  ...        True  False   False
# 23812  id_fffcb9e7c     com_droga     24  ...       False  False   False
# 23813  id_ffffdd77b     com_droga     72  ...       False  False   False
#
# [23814 rows x 882 columns]

# %%
dados_totais['eh_72h'] = dados_totais['tratamento'] == 72
dados_totais
# Out:
#                  id    tratamento  tempo  ... eh_24h eh_48h  eh_72h
# 0      id_000644bb2     com_droga     24  ...  False  False   False
# 1      id_000779bfc     com_droga     72  ...  False  False   False
# 2      id_000a6266a     com_droga     48  ...  False  False   False
# 3      id_0015fd391     com_droga     48  ...  False  False   False
# 4      id_001626bd3     com_droga     72  ...  False  False   False
# ...             ...           ...    ...  ...    ...    ...     ...
# 23809  id_fffb1ceed     com_droga     24  ...  False  False   False
# 23810  id_fffb70c0c     com_droga     24  ...  False  False   False
# 23811  id_fffc1c3f4  com_controle     48  ...  False  False   False
# 23812  id_fffcb9e7c     com_droga     24  ...  False  False   False
# 23813  id_ffffdd77b     com_droga     72  ...  False  False   False
#
# [23814 rows x 883 columns]

# %% [markdown]
# ### Desafio 04 - Estudar sobre combinações de DataFrames.

# %% [markdown]
# Similar aos joins do SQL.

# %% [markdown]
# ### Desafio 05 - Fazer análise mais detalhada considerando tempo e dose, para comparar as distribuições (escolher uma droga e comparar com controle).

# %%
plt.figure(figsize = (12,8))
sns.boxplot(data = dados_totais.query('composto in @composto_principal'), y = 'g-0', x = 'composto', hue = 'dose')

# %%
plt.figure(figsize = (12,8))
sns.boxplot(data = dados_totais.query('composto in @composto_principal'), y = 'g-0', x = 'composto', hue = 'tempo')

# %%
plt.figure(figsize = (12,8))
sns.boxplot(data = dados_totais.query('composto in @composto_principal'), y = 'g-0', x = 'composto', hue = 'tratamento')

# %% [markdown]
# ### Desafio 06 - Descobrir se temos algum composto que dependendo da configuração do experimento, ativa ou não ativa algum MOA (ou um MOA diferente).

# %%
plt.figure(figsize = (12,8))
sns.boxplot(data = dados_totais.query('composto in @composto_principal'), y = 'g-700', x = 'composto', hue = 'tempo')

# %% [markdown]
# No gene 700, o composto 87d714366 age de uma maneira diferente aos outros compostos e diferente também nas 3 variações de horas.

# %% [markdown]
# ### Desafio 07 - Descobrir se tempo algum composto que dependendo da configuração do experimento, ativa MOAs difentes.

# %% [markdown]
# Diferentes configurações podem ativar MOAs diferentes.

# %% [markdown]
# ### Desafio 08 - Resumo do que você aprendeu com os dados.

# %% [markdown]
# Função merge, que silimar ao join do SQL, possibilita a junção de dois DataFrames.
